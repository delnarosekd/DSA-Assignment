# %%
import pandas as pd
auto_data=pd.read_csv(r"C:/Users/DELNA ROSE/Downloads/diabetes_model.csv")
auto_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %% [markdown]
# # 1. count plot of outcome

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='Outcome',data=auto_data)
plt.show()

# %% [markdown]
# # 2. Effect of age on outcome using boxplot

# %%
import matplotlib.pyplot as plt
sns.boxplot(x=auto_data['Outcome'],y=auto_data['Age'],data=auto_data)
plt.title('effect of age on outcome')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 3. Chance of getting diabetes: violin plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.violinplot(y=auto_data['DiabetesPedigreeFunction'],x=auto_data['Outcome'],data=auto_data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 4. Relationship with insulin and glucose: SCATTER PLOT

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.scatterplot(x=auto_data['Insulin'],y=auto_data['Glucose'],data=auto_data,hue=auto_data['Outcome'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 5. Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.heatmap(auto_data.corr())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
